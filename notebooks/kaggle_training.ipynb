# %% [markdown]
# # AlphaBuilder v3.1 - Kaggle Training
#
# This notebook trains the AlphaBuilder neural network on Kaggle GPU.
#
# **Setup:**
# 1. Enable GPU T4 x2 in Settings → Accelerator
# 2. Add dataset: gustavomello9600/alphabuilder-warmup-data
# 3. Run All Cells
#
# **Expected runtime:** ~5 hours for 30 epochs
